# %% [markdown]
# <a href="https://colab.research.google.com/github/diasgarcia/codigos-alta-perfornance/blob/main/topicos_documentos_tarefas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exemplo de Aula
#
# Testando o bloco de código

# %%
print("Olá, Mundo!")
# Out:
# Olá, Mundo!

# %%
mensagem = 'Olá Colab!!!'

# %%
print(mensagem)
# Out:
# Olá Colab!!!

# %%
idade = 18

# %%
if idade < 18:
  print('Menor de 18 anos')
elif idade == 18:
  print('18 anos')
else:
  print('Maior de 18 anos')
# Out:
# 18 anos
